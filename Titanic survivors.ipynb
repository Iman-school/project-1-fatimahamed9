# %%
import pandas as pd

# %%
df = pd.read_csv('titanic-passengers.csv', sep=';')
df.head(5)
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False   True     False
# 4    False  False     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False   True     False
# 888  False   True     False
# 889  False   True     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Number of missing values in Age
df['Age'].isnull().sum()
# Out:
# 177

# %%
#Number of missing values in Cabin
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
#Number of missing values in Emabarked
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
import numpy as np
#we select numeric columns in the dataframe
numeric = df.select_dtypes(include=np.number)
numeric_columns = numeric.columns

# %%
#print the numeric coLumns
numeric
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            343       2  28.0      0      0  13.0000
# 1             76       3  25.0      0      0   7.6500
# 2            641       3  20.0      0      0   7.8542
# 3            568       3  29.0      0      4  21.0750
# 4            672       1  31.0      1      0  52.0000
# ..           ...     ...   ...    ...    ...      ...
# 886           10       2  14.0      1      0  30.0708
# 887           61       3  22.0      0      0   7.2292
# 888          535       3  30.0      0      0   8.6625
# 889          102       3   NaN      0      0   7.8958
# 890          428       2  19.0      0      0  26.0000
#
# [891 rows x 6 columns]

# %%
#we fiLl the NoN values of numeric columns with the avarage value
df['Age'].fillna(df['Age'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df = df.fillna(df.mode().iloc[0])
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare    Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000  B96 B98        S
# 1    male  25.0      0      0      348123   7.6500    F G73        S
# 2    male  20.0      0      0      350050   7.8542  B96 B98        S
# 3  female  29.0      0      4      349909  21.0750  B96 B98        S
# 4    male  31.0      1      0  F.C. 12750  52.0000      B71        S

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare    Cabin Embarked
# 0        0      0      248740  13.0000  B96 B98        S
# 1        0      0      348123   7.6500    F G73        S
# 2        0      0      350050   7.8542  B96 B98        S
# 3        0      4      349909  21.0750  B96 B98        S
# 4        1      0  F.C. 12750  52.0000      B71        S
# ..     ...    ...         ...      ...      ...      ...
# 886      1      0      237736  30.0708  B96 B98        C
# 887      0      0        2669   7.2292  B96 B98        C
# 888      0      0      315084   8.6625  B96 B98        S
# 889      0      0      349215   7.8958  B96 B98        S
# 890      0      0      250655  26.0000  B96 B98        S
#
# [891 rows x 12 columns]>

# %%
df.drop('Cabin',axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df.drop('PassengerId',axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %%
df.drop('Ticket',axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  891 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  891 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 69.6+ KB

# %%
#We will create a new feature (column) called family_size by combining ‘SibSp’(Sibling & Spouse) and ‘Parch’(Parent & Children).
def create_fam_size(df):
    return df["SibSp"] + df["Parch"] + 1
df["family_size"] = create_fam_size(df)

# %%
df.head(10)
# Out:
#   Survived  Pclass                                               Name     Sex  \
# 0       No       2                         Collander, Mr. Erik Gustaf    male
# 1       No       3                            Moen, Mr. Sigurd Hansen    male
# 2       No       3                             Jensen, Mr. Hans Peder    male
# 3       No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
# 4       No       1                             Davidson, Mr. Thornton    male
# 5       No       3                     Gustafsson, Mr. Anders Vilhelm    male
# 6       No       3                               Patchett, Mr. George    male
# 7      Yes       3                        Nakid, Miss. Maria ("Mary")  female
# 8       No       3                    Lovell, Mr. John Hall ("Henry")    male
# 9      Yes       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female
#
#     Age  SibSp  Parch     Fare Embarked  family_size
# 0  28.0      0      0  13.0000        S            1
# 1  25.0      0      0   7.6500        S            1
# 2  20.0      0      0   7.8542        S            1
# 3  29.0      0      4  21.0750        S            5
# 4  31.0      1      0  52.0000        S            2
# 5  37.0      2      0   7.9250        S            3
# 6  19.0      0      0  14.5000        S            1
# 7   1.0      0      2  15.7417        C            3
# 8  20.5      0      0   7.2500        S            1
# 9  42.0      1      0  26.0000        S            2

# %%
import re
def create_categorical_title(df):
    def find_title(name: str) -> str:
        search = re.search(
            " ([A-Za-z]+)\.", name
        )  # Search for a word with a point at the end
        if search:
            title = search.group(1)
            if title in ["Mlle", "Ms"]:
                return "Miss"
            elif title in ["Mme", "Mrs"]:
                return "Mrs"
            elif title == "Mr":
                return "Mr"
            else:
                return "Rare"
        return ""

    return_title = df["Name"].apply(find_title)
    dict_title = {"Miss": 1, "Mrs": 2, "Mr": 3, "Rare": 4}
    return return_title.replace(dict_title)


df["Title"] = create_categorical_title(df)

# %%
df.head(10)
# Out:
#   Survived  Pclass                                               Name     Sex  \
# 0       No       2                         Collander, Mr. Erik Gustaf    male
# 1       No       3                            Moen, Mr. Sigurd Hansen    male
# 2       No       3                             Jensen, Mr. Hans Peder    male
# 3       No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
# 4       No       1                             Davidson, Mr. Thornton    male
# 5       No       3                     Gustafsson, Mr. Anders Vilhelm    male
# 6       No       3                               Patchett, Mr. George    male
# 7      Yes       3                        Nakid, Miss. Maria ("Mary")  female
# 8       No       3                    Lovell, Mr. John Hall ("Henry")    male
# 9      Yes       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female
#
#     Age  SibSp  Parch     Fare Embarked  family_size  Title
# 0  28.0      0      0  13.0000        S            1      3
# 1  25.0      0      0   7.6500        S            1      3
# 2  20.0      0      0   7.8542        S            1      3
# 3  29.0      0      4  21.0750        S            5      2
# 4  31.0      1      0  52.0000        S            2      3
# 5  37.0      2      0   7.9250        S            3      3
# 6  19.0      0      0  14.5000        S            1      3
# 7   1.0      0      2  15.7417        C            3      4
# 8  20.5      0      0   7.2500        S            1      3
# 9  42.0      1      0  26.0000        S            2      2

# %%
def titanic_children(passenger):
    
    age , sex = passenger
    if age <16:
        return 'child'
    else:
        return sex
df['person'] = df[['Age','Sex']].apply(titanic_children,axis=1)

# %%
df.head(20)
# Out:
#    Survived  Pclass                                               Name  \
# 0        No       2                         Collander, Mr. Erik Gustaf
# 1        No       3                            Moen, Mr. Sigurd Hansen
# 2        No       3                             Jensen, Mr. Hans Peder
# 3        No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4        No       1                             Davidson, Mr. Thornton
# 5        No       3                     Gustafsson, Mr. Anders Vilhelm
# 6        No       3                               Patchett, Mr. George
# 7       Yes       3                        Nakid, Miss. Maria ("Mary")
# 8        No       3                    Lovell, Mr. John Hall ("Henry")
# 9       Yes       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...
# 10       No       2                     Sobey, Mr. Samuel James Hayden
# 11       No       3                                Haas, Miss. Aloisia
# 12      Yes       2                   Herman, Mrs. Samuel (Jane Laver)
# 13       No       2                            Chapman, Mr. John Henry
# 14       No       3                                McMahon, Mr. Martin
# 15       No       3                         Kallio, Mr. Nikolai Erland
# 16       No       1                          Widener, Mr. Harry Elkins
# 17       No       3                               Elias, Mr. Joseph Jr
# 18       No       2                                 Hickman, Mr. Lewis
# 19      Yes       1                       Hoyt, Mr. Frederick Maxfield
#
#        Sex        Age  SibSp  Parch      Fare Embarked  family_size  Title  \
# 0     male  28.000000      0      0   13.0000        S            1      3
# 1     male  25.000000      0      0    7.6500        S            1      3
# 2     male  20.000000      0      0    7.8542        S            1      3
# 3   female  29.000000      0      4   21.0750        S            5      2
# 4     male  31.000000      1      0   52.0000        S            2      3
# 5     male  37.000000      2      0    7.9250        S            3      3
# 6     male  19.000000      0      0   14.5000        S            1      3
# 7   female   1.000000      0      2   15.7417        C            3      4
# 8     male  20.500000      0      0    7.2500        S            1      3
# 9   female  42.000000      1      0   26.0000        S            2      2
# 10    male  25.000000      0      0   13.0000        S            1      3
# 11  female  24.000000      0      0    8.8500        S            1      4
# 12  female  48.000000      1      2   65.0000        S            4      2
# 13    male  37.000000      1      0   26.0000        S            2      3
# 14    male  29.699118      0      0    7.7500        Q            1      3
# 15    male  17.000000      0      0    7.1250        S            1      3
# 16    male  27.000000      0      2  211.5000        C            3      3
# 17    male  17.000000      1      1    7.2292        C            3      3
# 18    male  32.000000      2      0   73.5000        S            3      3
# 19    male  38.000000      1      0   90.0000        S            2      3
#
#     person
# 0     male
# 1     male
# 2     male
# 3   female
# 4     male
# 5     male
# 6     male
# 7    child
# 8     male
# 9   female
# 10    male
# 11  female
# 12  female
# 13    male
# 14    male
# 15    male
# 16    male
# 17    male
# 18    male
# 19    male

# %%
df["person"].value_counts() #Get a number of male and female
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
df["Alone"] = df.family_size

# %%
df["Alone"].loc[df["Alone"]>0] = "with Family"
df["Alone"].loc[df["Alone"]==0] = "without Family"
# Out:
# C:\Users\fatim\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.head(15)
# Out:
#    Survived  Pclass                                               Name  \
# 0        No       2                         Collander, Mr. Erik Gustaf
# 1        No       3                            Moen, Mr. Sigurd Hansen
# 2        No       3                             Jensen, Mr. Hans Peder
# 3        No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4        No       1                             Davidson, Mr. Thornton
# 5        No       3                     Gustafsson, Mr. Anders Vilhelm
# 6        No       3                               Patchett, Mr. George
# 7       Yes       3                        Nakid, Miss. Maria ("Mary")
# 8        No       3                    Lovell, Mr. John Hall ("Henry")
# 9       Yes       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...
# 10       No       2                     Sobey, Mr. Samuel James Hayden
# 11       No       3                                Haas, Miss. Aloisia
# 12      Yes       2                   Herman, Mrs. Samuel (Jane Laver)
# 13       No       2                            Chapman, Mr. John Henry
# 14       No       3                                McMahon, Mr. Martin
#
#        Sex        Age  SibSp  Parch     Fare Embarked  family_size  Title  \
# 0     male  28.000000      0      0  13.0000        S            1      3
# 1     male  25.000000      0      0   7.6500        S            1      3
# 2     male  20.000000      0      0   7.8542        S            1      3
# 3   female  29.000000      0      4  21.0750        S            5      2
# 4     male  31.000000      1      0  52.0000        S            2      3
# 5     male  37.000000      2      0   7.9250        S            3      3
# 6     male  19.000000      0      0  14.5000        S            1      3
# 7   female   1.000000      0      2  15.7417        C            3      4
# 8     male  20.500000      0      0   7.2500        S            1      3
# 9   female  42.000000      1      0  26.0000        S            2      2
# 10    male  25.000000      0      0  13.0000        S            1      3
# 11  female  24.000000      0      0   8.8500        S            1      4
# 12  female  48.000000      1      2  65.0000        S            4      2
# 13    male  37.000000      1      0  26.0000        S            2      3
# 14    male  29.699118      0      0   7.7500        Q            1      3
#
#     person        Alone
# 0     male  with Family
# 1     male  with Family
# 2     male  with Family
# 3   female  with Family
# 4     male  with Family
# 5     male  with Family
# 6     male  with Family
# 7    child  with Family
# 8     male  with Family
# 9   female  with Family
# 10    male  with Family
# 11  female  with Family
# 12  female  with Family
# 13    male  with Family
# 14    male  with Family

# %%
df["Survived"].value_counts() #Get a number of who is Survived or not
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
cleanup_Survived = {"Survived":{"No": 0, "Yes": 1}}

# %%
df = df.replace(cleanup_Survived)#replace Yes & No with 0 & 1
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       2                         Collander, Mr. Erik Gustaf
# 1         0       3                            Moen, Mr. Sigurd Hansen
# 2         0       3                             Jensen, Mr. Hans Peder
# 3         0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         0       1                             Davidson, Mr. Thornton
# 5         0       3                     Gustafsson, Mr. Anders Vilhelm
# 6         0       3                               Patchett, Mr. George
# 7         1       3                        Nakid, Miss. Maria ("Mary")
# 8         0       3                    Lovell, Mr. John Hall ("Henry")
# 9         1       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...
#
#       Sex   Age  SibSp  Parch     Fare Embarked  family_size  Title  person  \
# 0    male  28.0      0      0  13.0000        S            1      3    male
# 1    male  25.0      0      0   7.6500        S            1      3    male
# 2    male  20.0      0      0   7.8542        S            1      3    male
# 3  female  29.0      0      4  21.0750        S            5      2  female
# 4    male  31.0      1      0  52.0000        S            2      3    male
# 5    male  37.0      2      0   7.9250        S            3      3    male
# 6    male  19.0      0      0  14.5000        S            1      3    male
# 7  female   1.0      0      2  15.7417        C            3      4   child
# 8    male  20.5      0      0   7.2500        S            1      3    male
# 9  female  42.0      1      0  26.0000        S            2      2  female
#
#          Alone
# 0  with Family
# 1  with Family
# 2  with Family
# 3  with Family
# 4  with Family
# 5  with Family
# 6  with Family
# 7  with Family
# 8  with Family
# 9  with Family

# %%
df["person"].value_counts() #Get a number of male and female
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
cleanup_Sex = {"person":     {"female": 0, "male": 1 , "child": 3}}

# %%
df = df.replace(cleanup_Sex)
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       2                         Collander, Mr. Erik Gustaf
# 1         0       3                            Moen, Mr. Sigurd Hansen
# 2         0       3                             Jensen, Mr. Hans Peder
# 3         0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         0       1                             Davidson, Mr. Thornton
# 5         0       3                     Gustafsson, Mr. Anders Vilhelm
# 6         0       3                               Patchett, Mr. George
# 7         1       3                        Nakid, Miss. Maria ("Mary")
# 8         0       3                    Lovell, Mr. John Hall ("Henry")
# 9         1       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...
#
#       Sex   Age  SibSp  Parch     Fare Embarked  family_size  Title  person  \
# 0    male  28.0      0      0  13.0000        S            1      3       1
# 1    male  25.0      0      0   7.6500        S            1      3       1
# 2    male  20.0      0      0   7.8542        S            1      3       1
# 3  female  29.0      0      4  21.0750        S            5      2       0
# 4    male  31.0      1      0  52.0000        S            2      3       1
# 5    male  37.0      2      0   7.9250        S            3      3       1
# 6    male  19.0      0      0  14.5000        S            1      3       1
# 7  female   1.0      0      2  15.7417        C            3      4       3
# 8    male  20.5      0      0   7.2500        S            1      3       1
# 9  female  42.0      1      0  26.0000        S            2      2       0
#
#          Alone
# 0  with Family
# 1  with Family
# 2  with Family
# 3  with Family
# 4  with Family
# 5  with Family
# 6  with Family
# 7  with Family
# 8  with Family
# 9  with Family

# %%
df["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
cleanup_Embarked =  {"Embarked":     {"S": 1, "C": 2, "Q": 3}}

# %%
df = df.replace(cleanup_Embarked)
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       2                         Collander, Mr. Erik Gustaf
# 1         0       3                            Moen, Mr. Sigurd Hansen
# 2         0       3                             Jensen, Mr. Hans Peder
# 3         0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         0       1                             Davidson, Mr. Thornton
# 5         0       3                     Gustafsson, Mr. Anders Vilhelm
# 6         0       3                               Patchett, Mr. George
# 7         1       3                        Nakid, Miss. Maria ("Mary")
# 8         0       3                    Lovell, Mr. John Hall ("Henry")
# 9         1       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...
#
#       Sex   Age  SibSp  Parch     Fare  Embarked  family_size  Title  person  \
# 0    male  28.0      0      0  13.0000         1            1      3       1
# 1    male  25.0      0      0   7.6500         1            1      3       1
# 2    male  20.0      0      0   7.8542         1            1      3       1
# 3  female  29.0      0      4  21.0750         1            5      2       0
# 4    male  31.0      1      0  52.0000         1            2      3       1
# 5    male  37.0      2      0   7.9250         1            3      3       1
# 6    male  19.0      0      0  14.5000         1            1      3       1
# 7  female   1.0      0      2  15.7417         2            3      4       3
# 8    male  20.5      0      0   7.2500         1            1      3       1
# 9  female  42.0      1      0  26.0000         1            2      2       0
#
#          Alone
# 0  with Family
# 1  with Family
# 2  with Family
# 3  with Family
# 4  with Family
# 5  with Family
# 6  with Family
# 7  with Family
# 8  with Family
# 9  with Family

# %%
df["Alone"].value_counts()
# Out:
# with Family    891
# Name: Alone, dtype: int64

# %%
cleanup_Alone =  {"Alone":     {"With Family": 1, "Without Family": 2}}

# %%
df = df.replace(cleanup_Alone)
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       2                         Collander, Mr. Erik Gustaf
# 1         0       3                            Moen, Mr. Sigurd Hansen
# 2         0       3                             Jensen, Mr. Hans Peder
# 3         0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         0       1                             Davidson, Mr. Thornton
# 5         0       3                     Gustafsson, Mr. Anders Vilhelm
# 6         0       3                               Patchett, Mr. George
# 7         1       3                        Nakid, Miss. Maria ("Mary")
# 8         0       3                    Lovell, Mr. John Hall ("Henry")
# 9         1       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...
#
#       Sex   Age  SibSp  Parch     Fare  Embarked  family_size  Title  person  \
# 0    male  28.0      0      0  13.0000         1            1      3       1
# 1    male  25.0      0      0   7.6500         1            1      3       1
# 2    male  20.0      0      0   7.8542         1            1      3       1
# 3  female  29.0      0      4  21.0750         1            5      2       0
# 4    male  31.0      1      0  52.0000         1            2      3       1
# 5    male  37.0      2      0   7.9250         1            3      3       1
# 6    male  19.0      0      0  14.5000         1            1      3       1
# 7  female   1.0      0      2  15.7417         2            3      4       3
# 8    male  20.5      0      0   7.2500         1            1      3       1
# 9  female  42.0      1      0  26.0000         1            2      2       0
#
#          Alone
# 0  with Family
# 1  with Family
# 2  with Family
# 3  with Family
# 4  with Family
# 5  with Family
# 6  with Family
# 7  with Family
# 8  with Family
# 9  with Family
